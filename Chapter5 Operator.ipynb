# %% [markdown]
# ## Question 1

# %%
# 2**3 + 5*7 - 9

# %% [markdown]
# ### solution

# %%
# 2**3 + 5*7 - 9
#  8   + 5*7 - 9
#  8   +  35 - 9
#      43    - 9
#            34

# %%
2**3 + 5*7 - 9
# Out:
# 34

# %% [markdown]
# ## Question 2

# %%
# 5*2**3 + 4*5

# %% [markdown]
# ### solution

# %%
# 5*2**3 + 4*5
# 5* 8   + 4*5
#  40    + 4*5
#  40    +  20
#        60

# %%
5*2**3 + 4*5
# Out:
# 60

# %% [markdown]
# ## Question 3

# %%
# 2**3**2

# %% [markdown]
# ### solution

# %%
# 2**3**2
# 2** 9
# 512

# %%
2**3**2
# Out:
# 512

# %% [markdown]
# ## Question 4

# %%
# 5 + 4 + 3 + 2 + 1

# %% [markdown]
# ### solution

# %%
# 5 + 4 + 3 + 2 + 1
#   9   + 3 + 2 + 1
#       12  + 2 + 1
#           14  + 1
#               15

# %%
5 + 4 + 3 + 2 + 1
# Out:
# 15

# %% [markdown]
# ## Question 5

# %%
# 7%2**2

# %% [markdown]
# ### solution

# %%
# 7%2**2
# 7% 4
#  3

# %%
7%2**2
# Out:
# 3

# %% [markdown]
# ## Question 6

# %%
# 7//(3**2**2 - 75)

# %% [markdown]
# ### solution

# %%
# 7//(3**2**2 - 75)
# 7//(3** 4   - 75)
# 7//( 81     - 75)
# 7//(        6)
#  1

# %%
7//(3**2**2 - 75)
# Out:
# 1

# %% [markdown]
# ## Question 7

# %%
# 6%7//3 + 2**3

# %% [markdown]
# ### solution

# %%
# 6%7//3 + 2**3
# 6%7//3 +  8
#  6 //3 +  8
#    2   +  8
#        10

# %%
6%7//3 + 2**3
# Out:
# 10

# %% [markdown]
# ## Question 8

# %%
# 5**2//(2*2 + 4)

# %% [markdown]
# ### solution

# %%
# 5**2//(2*2 + 4)
# 5**2//( 4  + 4)
# 5**2//     8  
#  25 //     8
#     3

# %%
5**2//(2*2 + 4)
# Out:
# 3

# %% [markdown]
# ## Question 9

# %%
# 1 + 2**3*1 - 1/2

# %% [markdown]
# ### solution

# %%
# 1 + 2**3*1 - 1/2
# 1 +  8  *1 - 1/2
# 1 +     8  - 1/2
# 1 +     8  - 0.5
#   9        - 0.5
#            8.5

# %%
1 + 2**3*1 - 1/2
# Out:
# 8.5

# %% [markdown]
# ## Question 10

# %%
# (1 + 2) + (3*4) - (2**3)

# %% [markdown]
# ### solution

# %%
# (1 + 2) + (3*4) - (2**3)
#    3    + (3*4) - (2**3)
#    3    +   12  - (2**3)
#    3    +   12  -   8
#         15      -   8
#                 7

# %%
(1 + 2) + (3*4) - (2**3)
# Out:
# 7

# %% [markdown]
# ## Question 11

# %%
# y = 2**2

# %% [markdown]
# ### solution

# %%
# y = 2**2
# y =  4

# %%
y = 2**2
print(y)
# Out:
# 4

# %% [markdown]
# ## Question 12

# %%
# y = 3**2/2**3

# %% [markdown]
# ### solution

# %%
# y = 3**2/2**3
# y =  9  /2**3
# y =  9  / 8
# y =     1.125

# %%
y = 3**2/2**3
print(y)
# Out:
# 1.125

# %% [markdown]
# ## Question 13

# %%
# y = 2**4**1/2

# %% [markdown]
# ### solution

# %%
# y = 2**4**1/2
# y = 2** 4  /2
# y =  16    /2
# y =        8

# %%
y = 2**4**1/2
print(y)
# Out:
# 8.0

# %% [markdown]
# ## Question 14

# %%
# y = 2*(4**2)%(8//2)

# %% [markdown]
# ### solution

# %%
# y = 2*(4**2)%(8//2)
# y = 2*( 16 )%(8//2)
# y = 2*( 16 )%( 4  )
# y =  32     %( 4  )
# y =         0

# %%
y = 2*(4**2)%(8//2)
print(y)
# Out:
# 0

# %% [markdown]
# ## Question 15

# %%
# y = 2*4 - 15 >= 1

# %% [markdown]
# ### solution

# %%
# y = 2*4 - 15 >= 1
# y =  8  - 15 >= 1
# y =     -7   >= 1
# y =          False

# %%
y = 2*4 - 15 >= 1
print(y)
# Out:
# False
