# %% [markdown]
# # -------------------- Numeric --------------------

# %% [markdown]
# ## Question1

# %%
numeric1 = 5
print(numeric1)
print(type(numeric1))
# Out:
# 5
# <class 'int'>

# %% [markdown]
# ## Question2

# %%
numeric2 = -3
print(numeric2)
print(type(numeric2))
# Out:
# -3
# <class 'int'>

# %% [markdown]
# ## Question3

# %%
numeric3 = 0
print(numeric3)
print(type(numeric3))
# Out:
# 0
# <class 'int'>

# %% [markdown]
# ## Question4

# %%
numeric4 = int(input('Please insert integer: '))
print(numeric4)
print(type(numeric4))
# Out:
# Please insert integer: 3
# 3
# <class 'int'>

# %% [markdown]
# ## Question5

# %%
numeric1 = 5.0
print(numeric1)
print(type(numeric1))
# Out:
# 5.0
# <class 'float'>

# %% [markdown]
# ## Question6

# %%
numeric2 = -3.1
print(numeric2)
print(type(numeric2))
# Out:
# -3.1
# <class 'float'>

# %% [markdown]
# ## Question7

# %%
numeric3 = 0.0
print(numeric3)
print(type(numeric3))
# Out:
# 0.0
# <class 'float'>

# %% [markdown]
# ## Question8

# %%
numeric4 = float(input('Please insert floating number: '))
print(numeric4)
print(type(numeric4))
# Out:
# Please insert floating number: 3.99
# 3.99
# <class 'float'>

# %% [markdown]
# ## Question9

# %%
int1 = int(input('Please insert int1: '))
int2 = int(input('Please insert int2: '))
print('int1:', int1, type(int1))

print('int2:', int2, type(int2))

a = int1 + int2
print('sum:', a, type(a))

b = int1 - int2
print('difference:', b, type(b))

c = int1*int2
print('product:', c, type(c))

d = int1/int2
print('quotient:', d, type(d))
# Out:
# Please insert int1: 17
# Please insert int2: 4
# int1: 17 <class 'int'>
# int2: 4 <class 'int'>
# sum: 21 <class 'int'>
# difference: 13 <class 'int'>
# product: 68 <class 'int'>
# quotient: 4.25 <class 'float'>

# %% [markdown]
# ## Question10

# %%
float1 = float(input('Please insert float1: '))
float2 = float(input('Please insert float2: '))
print('float1:', float1, type(float1))

print('float2:', float2, type(float2))

a = float1 + float2
print('sum', a, type(a))

b = float1 - float2
print('difference', b, type(b))

c = float1*float2
print('product', c, type(c))

d = float1/float2
print('quotient', d, type(d))
# Out:
# Please insert float1: 24.5
# Please insert float2: 2.4
# float1: 24.5 <class 'float'>
# float2: 2.4 <class 'float'>
# sum 26.9 <class 'float'>
# difference 22.1 <class 'float'>
# product 58.8 <class 'float'>
# quotient 10.208333333333334 <class 'float'>

# %% [markdown]
# ## Question11

# %%
int1 = int(input('Please insert int1: '))
float1 = float(input('Please insert float1: '))
print('int1:', int1, type(int1))

print('float1:', float1, type(float1))

a = int1 + float1
print('sum:', a, type(a))

b = int1 - float1
print('difference:', b, type(b))

c = int1*float1
print('product:', c, type(c))

d = int1/float1
print('quotient:', d, type(d))
# Out:
# Please insert int1: 5
# Please insert float1: 7.1
# int1: 5 <class 'int'>
# float1: 7.1 <class 'float'>
# sum: 12.1 <class 'float'>
# difference: -2.0999999999999996 <class 'float'>
# product: 35.5 <class 'float'>
# quotient: 0.7042253521126761 <class 'float'>

# %% [markdown]
# ## Question12

# %%
logic1 = True
print(logic1)
print(type(logic1))
# Out:
# True
# <class 'bool'>

# %% [markdown]
# ## Question13

# %%
logic2 = False
print(logic2)
print(type(logic2))
# Out:
# False
# <class 'bool'>

# %% [markdown]
# ## Question14

# %%
logic1 = True
logic2 = False
print((logic1 and logic2))
# Out:
# False

# %% [markdown]
# ## Question15

# %%
logic1 = True
logic2 = False
print((logic1 or logic2))
# Out:
# True

# %% [markdown]
# ## Question16

# %%
complex1 = 1 + 2j
print(complex1)
print(type(complex1))
# Out:
# (1+2j)
# <class 'complex'>

# %% [markdown]
# ## Question17

# %%
complex1 = 1 + 2j
print(complex1.real)
# Out:
# 1.0

# %% [markdown]
# ## Question18

# %%
complex1 = 1 + 2j
print(complex1.imag)
# Out:
# 2.0

# %% [markdown]
# # -------------------- String --------------------

# %% [markdown]
# ## Question19

# %%
string1 = 'Python'
print(string1)
print(type(string1))
# Out:
# Python
# <class 'str'>

# %% [markdown]
# ## Question20

# %%
string1 = 'Python'
print(string1[0])
# Out:
# P

# %% [markdown]
# ## Question21

# %%
string1 = 'Python'
print(string1[1])
# Out:
# y

# %% [markdown]
# ## Question22

# %%
string1 = 'Python'
print(string1[-1])
# Out:
# n

# %% [markdown]
# ## Question23

# %%
string1 = 'Python'
print(string1[-2])
# Out:
# o

# %% [markdown]
# ## Question24

# %% [markdown]
# ### Solution 24.1 (recommend)

# %%
string1 = 'Python'
print(string1[2])
# Out:
# t

# %% [markdown]
# ### Solution 24.2

# %%
string1 = 'Python'
print(string1[-4])
# Out:
# t

# %% [markdown]
# ## Question25

# %% [markdown]
# ### Solution 25.1 (recommend)

# %%
string1 = 'Python'
print(string1[3])
# Out:
# h

# %% [markdown]
# ### Solution 25.2

# %%
string1 = 'Python'
print(string1[-3])
# Out:
# h

# %% [markdown]
# ## Question26

# %%
string1 = 'Python'
print(string1[1:4])
# Out:
# yth

# %% [markdown]
# ## Question27

# %%
string1 = 'Python'
print(string1[2:-1])
# Out:
# tho

# %% [markdown]
# ## Question28

# %%
string1 = 'Python'
print(string1[2:])
# Out:
# thon

# %% [markdown]
# ## Question29

# %%
string1 = 'Python'
print(string1[-4:5])
# Out:
# tho

# %% [markdown]
# ## Question30

# %% [markdown]
# ### Solution 30.1 (recommend)

# %%
string1 = 'Python'
print(string1[-6:5])
# Out:
# Pytho

# %% [markdown]
# ### Solution 30.2

# %%
string1 = 'Python'
print(string1[:5])
# Out:
# Pytho

# %% [markdown]
# ## Question31

# %%
string1 = 'Python'
print(string1[-4:-1])
# Out:
# tho

# %% [markdown]
# ## Question32

# %%
string1 = input('Please insert string1: ')
print(len(string1))
# Out:
# Please insert string1: hello
# 5

# %% [markdown]
# ## Question33

# %%
string1 = input('Please insert string1: ')
print('a' in string1)
# Out:
# Please insert string1: absolute
# True

# %% [markdown]
# ## Question34

# %%
string1 = input('Please insert string1: ')
string2 = input('Please insert string2: ')
print(string2 in string1)
# Out:
# Please insert string1: abcde
# Please insert string2: cd
# True

# %% [markdown]
# ## Question35

# %%
string1 = input('Please insert string1: ')
print(string1.replace('a', 'A'))
# Out:
# Please insert string1: abcd
# Abcd

# %% [markdown]
# ## Question36

# %%
string1 = input('Please insert string1: ')
string2 = string1.replace('a', 'A')
print(string2)
# Out:
# Please insert string1: aaa
# AAA

# %% [markdown]
# ## Question37

# %%
sentence = input('Please insert sentence: ')
print(sentence.split(' '))
# Out:
# Please insert sentence: learning python is good for you
# ['learning', 'python', 'is', 'good', 'for', 'you']

# %% [markdown]
# ## Question38

# %%
sentence = input('Please insert sentence: ')
c = input('Please insert c: ')
print(sentence.split(c))
# Out:
# Please insert sentence: one-two-three
# Please insert c: -
# ['one', 'two', 'three']

# %% [markdown]
# ## Question39

# %%
str1 = input('Please insert str1: ')
str2 = input('Please insert str2: ')
print(str1 + str2)
# Out:
# Please insert str1: ab
# Please insert str2: cd
# abcd

# %% [markdown]
# ## Question40

# %%
list1 = [0, 1, 2, 'a', 'b', 'c']
print(list1)
print(type(list1))
# Out:
# [0, 1, 2, 'a', 'b', 'c']
# <class 'list'>

# %% [markdown]
# ## Question41

# %%
list1 = [0, 1, 2, 'a', 'b', 'c']
print(list1[2])
# Out:
# 2

# %% [markdown]
# ## Question42

# %%
list1 = [0, 1, 2, 'a', 'b', 'c']
print(list1[-3])
# Out:
# a

# %% [markdown]
# ## Question43

# %% [markdown]
# ### Solution 43.1 (recommend)

# %%
list1 = [0, 1, 2, 'a', 'b', 'c']
print(list1[0])
# Out:
# 0

# %% [markdown]
# ### Solution 43.2

# %%
list1 = [0, 1, 2, 'a', 'b', 'c']
print(list1[-6])
# Out:
# 0

# %% [markdown]
# ## Question44

# %% [markdown]
# ### Solution 44.1 (recommend)

# %%
list1 = [0, 1, 2, 'a', 'b', 'c']
print(list1[-2])
# Out:
# b

# %% [markdown]
# ### Solution 44.2

# %%
list1 = [0, 1, 2, 'a', 'b', 'c']
print(list1[4])
# Out:
# b

# %% [markdown]
# ## Question45

# %%
list1 = [0, 1, 2, 'a', 'b', 'c']
print(list1[2:4])
# Out:
# [2, 'a']

# %% [markdown]
# ## Question46

# %%
list1 = [0, 1, 2, 'a', 'b', 'c']
print(list1[1:-1])
# Out:
# [1, 2, 'a', 'b']

# %% [markdown]
# ## Question47

# %% [markdown]
# ### Solution 47.1 (recommend)

# %%
list1 = [0, 1, 2, 'a', 'b', 'c']
print(list1[1:5])
# Out:
# [1, 2, 'a', 'b']

# %% [markdown]
# ### Solution 47.2

# %%
list1 = [0, 1, 2, 'a', 'b', 'c']
print(list1[1:-1])
# Out:
# [1, 2, 'a', 'b']

# %% [markdown]
# ### Solution 47.3

# %%
list1 = [0, 1, 2, 'a', 'b', 'c']
print(list1[-5:5])
# Out:
# [1, 2, 'a', 'b']

# %% [markdown]
# ### Solution 47.4

# %%
list1 = [0, 1, 2, 'a', 'b', 'c']
print(list1[-5:-1])
# Out:
# [1, 2, 'a', 'b']

# %% [markdown]
# ## Question48

# %% [markdown]
# ### Solution 48.1 (recommend)

# %%
list1 = [0, 1, 2, 'a', 'b', 'c']
print(list1[3:])
# Out:
# ['a', 'b', 'c']

# %% [markdown]
# ### Solution 48.2

# %%
list1 = [0, 1, 2, 'a', 'b', 'c']
print(list1[-3:])
# Out:
# ['a', 'b', 'c']

# %% [markdown]
# ## Question49

# %% [markdown]
# ### Solution 49.1 (recommend)

# %%
list1 = [0, 1, 2, 'a', 'b', 'c']
print(list1[:3])
# Out:
# [0, 1, 2]

# %% [markdown]
# ### Solution 49.2

# %%
list1 = [0, 1, 2, 'a', 'b', 'c']
print(list1[:-3])
# Out:
# [0, 1, 2]

# %% [markdown]
# ## Question50

# %%
list2 = ['ant', 'bird', 'cat', 'dog', 'eagle']
list2[3] = 'duck'
print(list2)
# Out:
# ['ant', 'bird', 'cat', 'duck', 'eagle']

# %% [markdown]
# ## Question51

# %% [markdown]
# ### Solution 51.1 (recommend)

# %%
list2 = ['ant', 'bird', 'cat', 'dog', 'eagle']
list2[0] = 'ape'
print(list2)
# Out:
# ['ape', 'bird', 'cat', 'dog', 'eagle']

# %% [markdown]
# ### Solution 51.2

# %%
list2 = ['ant', 'bird', 'cat', 'dog', 'eagle']
list2[-5] = 'ape'
print(list2)
# Out:
# ['ape', 'bird', 'cat', 'dog', 'eagle']

# %% [markdown]
# ## Question52

# %%
list2 = ['ant', 'bird', 'cat', 'dog', 'eagle']
list2.append('fish')
print(list2)
# Out:
# ['ant', 'bird', 'cat', 'dog', 'eagle', 'fish']

# %% [markdown]
# ## Question53

# %%
list2 = []
str1 = input('Please insert first element: ')
str2 = input('Please insert second element: ')
str3 = input('Please insert third element: ')
list2.append(str1)
list2.append(str2)
list2.append(str3)
print(list2)
# Out:
# Please insert first element: ant
# Please insert second element: baboon
# Please insert third element: camel
# ['ant', 'baboon', 'camel']

# %% [markdown]
# ## Question54

# %%
list3 = ['apple', 'cherry', 'eggfruit']
list3.insert(1, 'banana')
print(list3)
# Out:
# ['apple', 'banana', 'cherry', 'eggfruit']

# %% [markdown]
# ## Question55

# %%
list3 = ['apple', 'banana', 'cherry', 'eggfruit']
list3.insert(-1, 'kiwi')
print(list3)
# Out:
# ['apple', 'banana', 'cherry', 'kiwi', 'eggfruit']

# %% [markdown]
# ## Question56

# %%
list4 = [0, 4, 2, 3, 1]
list4.sort()
print(list4)
# Out:
# [0, 1, 2, 3, 4]

# %% [markdown]
# ## Question57

# %%
list4 = [0, 4, 2, 3, 1]
list4.sort(reverse=True)
print(list4)
# Out:
# [4, 3, 2, 1, 0]

# %% [markdown]
# ## Question58

# %%
list4 = [0, 4, 2, 3, 1]
sorted_list4 = sorted(list4)
print(sorted_list4)
# Out:
# [0, 1, 2, 3, 4]

# %% [markdown]
# ## Question59

# %%
list4 = [0, 4, 2, 3, 1]
sorted_list4 = sorted(list4, reverse=True)
print(sorted_list4)
# Out:
# [4, 3, 2, 1, 0]

# %% [markdown]
# ## Question60

# %%
list5 = ['d', 'a', 'c', 'b', 'e']
list5.sort()
print(list5)
# Out:
# ['a', 'b', 'c', 'd', 'e']

# %% [markdown]
# ## Question61

# %%
list5 = ['d', 'a', 'c', 'b', 'e']
sorted_list5 = sorted(list5, reverse=True)
print(sorted_list5)
# Out:
# ['e', 'd', 'c', 'b', 'a']

# %% [markdown]
# ## Question62

# %%
list1 = ['a', 'b', 'c']
list2 = [0, 1, 2]
list1.extend(list2)
print(list1)
print(list2)
# Out:
# ['a', 'b', 'c', 0, 1, 2]
# [0, 1, 2]

# %% [markdown]
# ## Question63

# %%
list1 = ['a', 'b', 'c']
list2 = [0, 1, 2]
list3 = list1 + list2
print(list1)
print(list2)
print(list3)
# Out:
# ['a', 'b', 'c']
# [0, 1, 2]
# ['a', 'b', 'c', 0, 1, 2]

# %% [markdown]
# ## Question64

# %%
list1 = [1, 2, 3, 1, 2, 3]
del list1[1]
print(list1)
# Out:
# [1, 3, 1, 2, 3]

# %% [markdown]
# ## Question65

# %%
list1 = [1, 2, 3, 1, 2, 3]
del list1[-1]
del list1[2]
print(list1)
# Out:
# [1, 2, 1, 2]

# %% [markdown]
# ## Question66

# %%
list1 = [1, 2, 3, 1, 2, 3]
list1.remove(1)
print(list1)
# Out:
# [2, 3, 1, 2, 3]

# %% [markdown]
# ## Question67

# %%
list1 = [1, 2, 3, 1, 2, 3]
list1.remove(1)
list1.remove(1)
print(list1)
# Out:
# [2, 3, 2, 3]

# %% [markdown]
# ## Question68

# %%
list1 = [1, 2, 3, 1, 2, 3]
list1.clear()
print(list1)
# Out:
# []

# %% [markdown]
# ## Question69

# %%
list1 = [1, 2, 3, 'a', 'b', 'c']
print(len(list1))
# Out:
# 6

# %% [markdown]
# ## Question70

# %%
list1 = [1, 2, 3, 4, 5]
numeric1 = int(input('Please insert numeric1: '))
print(numeric1 in list1)
# Out:
# Please insert numeric1: 4
# True

# %% [markdown]
# ## Question71

# %%
tuple1 = ('America', 'Brazil', 'China', 'Dominican', 'Egypt')
print(tuple1)
print(type(tuple1))
# Out:
# ('America', 'Brazil', 'China', 'Dominican', 'Egypt')
# <class 'tuple'>

# %% [markdown]
# ## Question72

# %%
tuple1 = ('America', 'Brazil', 'China', 'Dominican', 'Egypt')
print(tuple1[1])
# Out:
# Brazil

# %% [markdown]
# ## Question73

# %%
tuple1 = ('America', 'Brazil', 'China', 'Dominican', 'Egypt')
print(tuple1[-2])
# Out:
# Dominican

# %% [markdown]
# ## Question74

# %% [markdown]
# ### Solution 74.1 (recommend)

# %%
tuple1 = ('America', 'Brazil', 'China', 'Dominican', 'Egypt')
print(tuple1[2])
# Out:
# China

# %% [markdown]
# ### Solution 74.2

# %%
tuple1 = ('America', 'Brazil', 'China', 'Dominican', 'Egypt')
print(tuple1[-3])
# Out:
# China

# %% [markdown]
# ## Question75

# %% [markdown]
# ### Solution 75.1 (recommend)

# %%
tuple1 = ('America', 'Brazil', 'China', 'Dominican', 'Egypt')
print(tuple1[-1])
# Out:
# Egypt

# %% [markdown]
# ### Solution 75.2

# %%
tuple1 = ('America', 'Brazil', 'China', 'Dominican', 'Egypt')
print(tuple1[4])
# Out:
# Egypt

# %% [markdown]
# ## Question76

# %%
tuple2 = ('one', 'two', 'three', 1, 2, 3)
print(tuple2[1:4])
# Out:
# ('two', 'three', 1)

# %% [markdown]
# ## Question77

# %%
tuple2 = ('one', 'two', 'three', 1, 2, 3)
print(tuple2[2:-1])
# Out:
# ('three', 1, 2)

# %% [markdown]
# ## Question78

# %% [markdown]
# ### Solution 78.1 (recommend)

# %%
tuple2 = ('one', 'two', 'three', 1, 2, 3)
print(tuple2[2:4])
# Out:
# ('three', 1)

# %% [markdown]
# ### Solution 78.2

# %%
tuple2 = ('one', 'two', 'three', 1, 2, 3)
print(tuple2[2:-2])
# Out:
# ('three', 1)

# %% [markdown]
# ### Solution 78.3

# %%
tuple2 = ('one', 'two', 'three', 1, 2, 3)
print(tuple2[-4:4])
# Out:
# ('three', 1)

# %% [markdown]
# ### Solution 78.4

# %%
tuple2 = ('one', 'two', 'three', 1, 2, 3)
print(tuple2[-4:-2])
# Out:
# ('three', 1)

# %% [markdown]
# ## Question79

# %% [markdown]
# ### Solution 79.1 (recommend)

# %%
tuple2 = ('one', 'two', 'three', 1, 2, 3)
print(tuple2[:3])
# Out:
# ('one', 'two', 'three')

# %% [markdown]
# ### Solution 79.2

# %%
tuple2 = ('one', 'two', 'three', 1, 2, 3)
print(tuple2[:-3])
# Out:
# ('one', 'two', 'three')

# %% [markdown]
# ## Question80

# %% [markdown]
# ### Solution 80.1 (recommend)

# %%
tuple2 = ('one', 'two', 'three', 1, 2, 3)
print(tuple2[3:])
# Out:
# (1, 2, 3)

# %% [markdown]
# ### Solution 80.2

# %%
tuple2 = ('one', 'two', 'three', 1, 2, 3)
print(tuple2[-3:])
# Out:
# (1, 2, 3)

# %% [markdown]
# ## Question81

# %%
tuple3 = ('one', 'two', 'three', 'four', 'five')
print(len(tuple3))
# Out:
# 5

# %% [markdown]
# ## Question82

# %%
tuple3 = ('one', 'two', 'three', 'four', 'five')
str1 = input('Please insert str1: ')
print(str1 in tuple3)
# Out:
# Please insert str1: three
# True

# %% [markdown]
# ## Question83

# %%
dict1 = {'first_name' : 'John', 'last_name' : 'Doe'}
print(dict1)
print(type(dict1))
# Out:
# {'first_name': 'John', 'last_name': 'Doe'}
# <class 'dict'>

# %% [markdown]
# ## Question84

# %%
dict1 = {'first_name' : 'John', 'last_name' : 'Doe'}
print(dict1['first_name'])
# Out:
# John

# %% [markdown]
# ## Question85

# %%
dict1 = {'first_name' : 'John', 'last_name' : 'Doe'}
print(dict1['last_name'])
# Out:
# Doe

# %% [markdown]
# ## Question86

# %%
dict1 = {'first_name' : 'John', 'last_name' : 'Doe'}
print(dict1.keys())
# Out:
# dict_keys(['first_name', 'last_name'])

# %% [markdown]
# ## Question87

# %%
dict1 = {'first_name' : 'John', 'last_name' : 'Doe'}
print(dict1.values())
# Out:
# dict_values(['John', 'Doe'])

# %% [markdown]
# ## Question88

# %%
dict1 = {'first_name' : 'John', 'last_name' : 'Doe'}
dict1['first_name'] = 'Jane'
print(dict1)
# Out:
# {'first_name': 'Jane', 'last_name': 'Doe'}

# %% [markdown]
# ## Question89

# %%
dict1 = {'first_name' : 'John', 'last_name' : 'Doe'}
dict1['age'] = 32
print(dict1)
# Out:
# {'first_name': 'John', 'last_name': 'Doe', 'age': 32}

# %% [markdown]
# ## Question90

# %%
dict1 = {'first_name' : 'John', 'last_name' : 'Doe'}
dict1.update({'age' : 32, 'hobby' : ['coding', 'studying']})
print(dict1)
# Out:
# {'first_name': 'John', 'last_name': 'Doe', 'age': 32, 'hobby': ['coding', 'studying']}

# %% [markdown]
# ## Question91

# %%
dict1 = {}
str1 = input('Please insert str1: ')
str2 = input('Please insert str2: ')
dict1[str1] = str2
print(dict1)
# Out:
# Please insert str1: a
# Please insert str2: A
# {'a': 'A'}

# %% [markdown]
# ## Question92

# %%
dict1 = {'first_name' : 'John', 'last_name' : 'Doe', 'age' : 32}
del dict1['age']
print(dict1)
# Out:
# {'first_name': 'John', 'last_name': 'Doe'}

# %% [markdown]
# ## Question93

# %%
dict1 = {'first_name' : 'John', 'last_name' : 'Doe', 'age' : 32}
dict1.clear()
print(dict1)
# Out:
# {}

# %% [markdown]
# ## Question94

# %% [markdown]
# ### Solution 94.1 (recommend)

# %%
dict1 = {'first_name' : 'John', 'last_name' : 'Doe', 'age' : 32}
print(len(dict1))
# Out:
# 3

# %% [markdown]
# ### Solution 94.2

# %%
dict1 = {'first_name' : 'John', 'last_name' : 'Doe', 'age' : 32}
print(len(dict1.keys()))
# Out:
# 3

# %% [markdown]
# ## Question95

# %% [markdown]
# ### Solution 95.1 (recommend)

# %%
dict1 = {'first_name' : 'John', 'last_name' : 'Doe', 'age' : 32}
str1 = input('Please insert str1: ')
print(str1 in dict1)
# Out:
# Please insert str1: first_name
# True

# %% [markdown]
# ### 95.2 solution

# %%
dict1 = {'first_name' : 'John', 'last_name' : 'Doe', 'age' : 32}
str1 = input('Please insert str1: ')
print(str1 in dict1.keys())
# Out:
# Please insert str1: first_name
# True

# %% [markdown]
# ## Question96

# %%
dict1 = {'first_name' : 'John', 'last_name' : 'Doe', 'age' : 32}
str1 = input('Please insert str1: ')
print(str1 in dict1.values())
# Out:
# Please insert str1: Doe
# True

# %% [markdown]
# # -------------------- Set --------------------

# %% [markdown]
# ## Question97

# %%
set1 = {1, 2, 3, 'i', 'ii', 'iii'}
print(set1)
print(type(set1))
# Out:
# {1, 2, 3, 'ii', 'iii', 'i'}
# <class 'set'>

# %% [markdown]
# ## Question98

# %%
set1 = {1, 2, 3, 'i', 'ii', 'iii'}
for s in set1:
    print(s)
# Out:
# 1
# 2
# 3
# ii
# iii
# i

# %% [markdown]
# ## Question99

# %%
set1 = {1, 2, 3, 'i', 'ii', 'iii'}
set1.add('iv')
print(set1)
# Out:
# {1, 2, 3, 'iv', 'ii', 'iii', 'i'}

# %% [markdown]
# ## Question100

# %%
set1 = {1, 2, 3, 'i', 'ii', 'iii'}
set1.add(1)
print(set1)
# Out:
# {1, 2, 3, 'ii', 'iii', 'i'}

# %% [markdown]
# ## Question101

# %%
set1 = set()
str1 = input('Please insert str1: ')
str2 = input('Please insert str2: ')
str3 = input('Please insert str3: ')
set1.add(str1)
set1.add(str2)
set1.add(str3)
print(set1)
# Out:
# Please insert str1: x
# Please insert str2: y
# Please insert str3: z
# {'x', 'y', 'z'}

# %% [markdown]
# ## Question102

# %%
set1 = set()
str1 = input('Please insert str1: ')
str2 = input('Please insert str2: ')
str3 = input('Please insert str3: ')
set1.update({str1, str2, str3})
print(set1)
# Out:
# Please insert str1: 1
# Please insert str2: a
# Please insert str3: c
# {'1', 'a', 'c'}

# %% [markdown]
# ## Question103

# %%
set1 = {1, 2, 3, 'i', 'ii', 'iii'}
set1.remove('i')
print(set1)
# Out:
# {1, 2, 3, 'ii', 'iii'}

# %% [markdown]
# ## Question104

# %%
set1 = {1, 2, 3, 'i', 'ii', 'iii'}
print(len(set1))
# Out:
# 6

# %% [markdown]
# ## Question105

# %%
set1 = {1, 2, 3, 'i', 'ii', 'iii'}
int1 = int(input('Please insert numeric1: '))
print(int1 in set1)
# Out:
# Please insert numeric1: 2
# True

# %% [markdown]
# ## Question106

# %%
set1 = {1, 2, 3, 4, 5}
set2 = {3, 4, 5, 6}
print(set1 | set2)
# Out:
# {1, 2, 3, 4, 5, 6}

# %% [markdown]
# ## Question107

# %%
set1 = {1, 2, 3, 4, 5}
set2 = {3, 4, 5, 6}
print(set1 & set2)
# Out:
# {3, 4, 5}

# %% [markdown]
# ## Question108

# %%
set1 = {1, 2, 3, 4, 5}
set2 = {3, 4, 5, 6}
print(set1 - set2)
# Out:
# {1, 2}

# %% [markdown]
# ## Question109

# %%
set1 = {1, 2, 3, 4, 5}
set2 = {3, 4, 5, 6}
print(set2 - set1)
# Out:
# {6}

# %% [markdown]
# ## Question110

# %%
set1 = {1, 2, 3, 4, 5}
set2 = {3, 4, 5, 6}
print(set1 ^ set2)
# Out:
# {1, 2, 6}
