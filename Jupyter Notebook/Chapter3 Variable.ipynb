# %% [markdown]
# ## Question 1

# %%
name = 'John'

# %% [markdown]
# ## Question 2

# %%
_name = 'John'

# %% [markdown]
# ## Question 3

# %%
name1 = 'John'

# %% [markdown]
# ## Question 4

# %%
name! = 'John'
# Out:
#   File "<ipython-input-4-1000dc686d0e>", line 1
#     name! = 'John'
#         ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## Question 5

# %%
# !name = 'John'
# Out:
# 'name' is not recognized as an internal or external command,
# operable program or batch file.

# %% [markdown]
# ## Question 6

# %%
number = 20

# %% [markdown]
# ## Question 7

# %%
_number = 20

# %% [markdown]
# ## Question 8

# %%
@number = 20
# Out:
#   File "<ipython-input-8-1a90c41e7d5e>", line 1
#     @number = 20
#             ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## Question 9

# %%
number@ = 20
# Out:
#   File "<ipython-input-9-3707380bcc91>", line 1
#     number@ = 20
#             ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## Question 10

# %%
a5 = 20

# %% [markdown]
# ## Question 11

# %%
5a = 20
# Out:
#   File "<ipython-input-11-6b8e7bda5d76>", line 1
#     5a = 20
#      ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## Question 12

# %%
favorite_food = 'Hamburger'

# %% [markdown]
# ## Question 13

# %%
FavoriteFood = 'Hamburger'

# %% [markdown]
# ## Question 14

# %%
favorite food = 'Hamburger'
# Out:
#   File "<ipython-input-14-e2f621b1953a>", line 1
#     favorite food = 'Hamburger'
#              ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## Question 15

# %%
if = 7
# Out:
#   File "<ipython-input-15-9b6cbf7468bb>", line 1
#     if = 7
#        ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## Question 16

# %%
else = 5
# Out:
#   File "<ipython-input-16-49b8cd04d31e>", line 1
#     else = 5
#     ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## Question 17

# %%
for = 6
# Out:
#   File "<ipython-input-17-18b0d9e0afca>", line 1
#     for = 6
#         ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## Question 18

# %%
a = 5, b = 6, c = 7
# Out:
#   File "<ipython-input-18-f1764f036454>", line 1
#     a = 5, b = 6, c = 7
#         ^
# SyntaxError: cannot assign to literal

# %% [markdown]
# ## Question 19

# %%
a, b, c = 5, 6, 7

# %% [markdown]
# ## Question 20

# %%
a = 5; b = 6; c = 7
