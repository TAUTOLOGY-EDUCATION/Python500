# %% [markdown]
# ## Question 1

# %%
number = int(input('Please insert number: '))
if number%2 == 0:
    print('even number')
else:
    print('odd number')
# Out:
# Please insert number: 6
# even number

# %% [markdown]
# ## Question 2

# %%
number = int(input('Please insert number: '))
if number > 0:
    print('greater than 0')
else:
    print('less than or equal to 0')
# Out:
# Please insert number: 2
# greater than 0

# %% [markdown]
# ## Question 3

# %%
number = float(input('Please insert number: '))
if number > 0:
    print('positive')
elif number < 0:
    print('negative')
else:
    print('zero')
# Out:
# Please insert number: 0
# zero

# %% [markdown]
# ## Question 4

# %%
number = int(input('Please insert number: '))
if number > 0:
    if number%2 == 0:
        print('positive even')
    else:
        print('positive odd')
elif number < 0:
    if number%2 == 0:
        print('negative even')
    else:
        print('negative odd')
else:
    print('zero')
# Out:
# Please insert number: 7
# positive odd

# %% [markdown]
# ## Question 5

# %%
width = int(input('Please insert width: '))
length = int(input('Please insert length: '))
if (width <= 0) or (length <= 0):
    print('please enter positive integer')
else:
    area = width*length
    print(area)
# Out:
# Please insert width: 7
# Please insert length: 6
# 42

# %% [markdown]
# ## Question 6

# %%
AD = int(input('Please insert AD: '))
if AD >= 0:
    BE = AD + 543
    print(BE)
else:
    print('please enter a number that is greater than or equal to 0')
# Out:
# Please insert AD: 0
# 543

# %% [markdown]
# ## Question 7

# %%
F = float(input('Please insert F: '))
if F >= 32:
    C = 5*(F-32)/9
    print(C)
else:
    print('cold')
# Out:
# Please insert F: 64
# 17.77777777777778

# %% [markdown]
# ## Question 8

# %%
USD = float(input('Please insert USD: '))
if USD > 0:
    EUR = USD*0.85
    print(THB)
else:
    print("you don't have money")
# Out:
# Please insert USD: -7
# you don't have money

# %% [markdown]
# ## Question 9

# %%
EUR = float(input('Please insert EUR: '))
if EUR > 0:
    USD = EUR/0.85
    bank_profit = USD*0.01
    print('USD:',USD)
    print('profit:', bank_profit)
else:
    print("you don't have money")
# Out:
# Please insert EUR: 845
# USD: 994.1176470588235
# profit: 9.941176470588236

# %% [markdown]
# ## Question 10

# %%
num1 = float(input('Please insert num1: '))
num2 = float(input('Please insert num2: '))
if num1 > num2:
    print(num1)
elif num2 > num1:
    print(num2)
else:
    print('equal')
# Out:
# Please insert num1: 7
# Please insert num2: 6
# 7.0

# %% [markdown]
# ## Question 11

# %%
str1 = input('Please insert str1: ')
str2 = input('Please insert str2: ')
if len(str1) == len(str2):
    print('same')
else:
    print('not same')
# Out:
# Please insert str1: abc
# Please insert str2: cbd
# same

# %% [markdown]
# ## Question 12

# %%
number = int(input('Please insert number: '))
if number%3 == 0:
    print('divisible by 3')
else:
    print('not divisible by 3')
# Out:
# Please insert number: 20
# not divisible by 3

# %% [markdown]
# ## Question 13

# %%
number = int(input('Please insert number: '))
if (number%3 == 0) and (number%5 == 0):
    print('divisible by 3 and 5')
else:
    print('not divisible by 3 and 5')
# Out:
# Please insert number: 14
# not divisible by 3 and 5

# %% [markdown]
# ## Question 14

# %%
number = int(input('Please insert number: '))
if (number%3 == 0) or (number%5 == 0):
    print('divisible by 3 or 5')
else:
    print('not divisible by 3 or 5')
# Out:
# Please insert number: 11
# not divisible by 3 or 5

# %% [markdown]
# ## Question 15

# %%
a = float(input('Please insert a: '))
b = float(input('Please insert b: '))
c = float(input('Please insert c: '))
if a + b > c:
    print('a + b > c')
# Out:
# Please insert a: 1
# Please insert b: 2
# Please insert c: 3

# %% [markdown]
# ## Question 16

# %%
hour = int(input('Please insert hour: '))
minute = int(input('Please insert minute: '))
if minute > 0:
    hour = hour + 1
fee = (hour - 1)*2
print(fee)
# Out:
# Please insert hour: 1
# Please insert minute: 2
# 2

# %% [markdown]
# ## Question 17

# %%
hour = int(input('Please insert hour: '))
minute = int(input('Please insert minute: '))
if (hour < 0) or (minute < 0):
    print('please enter a non negative number')
else:
    if minute > 0:
        hour = hour + 1
    fee = (hour - 1)*2
    print(fee)
# Out:
# Please insert hour: 7
# Please insert minute: 6
# 14

# %% [markdown]
# ## Question 18

# %%
bill = int(input('Please insert bill: '))
hour = int(input('Please insert hour: '))
minute = int(input('Please insert minute: '))
if minute > 0:
    hour = hour + 1
if bill >= 1000:
    fee = (hour - 4)*3.5
    if fee < 0:
        fee = 0
else:
    fee = (hour - 1)*3.5
print(fee)
# Out:
# Please insert bill: 5000
# Please insert hour: 5
# Please insert minute: 5
# 7.0

# %% [markdown]
# ## Question 19

# %%
bill = float(input('Please insert bill: '))
if bill >= 1500:
    discount = bill*0.2
elif bill >= 300:
    discount = bill*0.15
elif bill >= 30:
    discount = bill*0.1
else:
    discount = 0
pay = bill - discount
print(pay)
# Out:
# Please insert bill: 5000
# 4000.0

# %% [markdown]
# ## Question 20

# %%
gender = input('Please insert gender: ')
weight = float(input('Please insert weight(kg): '))
height = int(input('Please insert height(cm): '))
BMI = weight/height**2
if gender == 'male':
    if BMI > 26.4:
        print('Should excercise')
    else:
        print('You have a great figure')
elif gender == 'female':
    if BMI > 25.8:
        print('Should excercise')
    else:
        print('You have a great figure')
# Out:
# Please insert gender: male
# Please insert weight(kg): 95
# Please insert height(cm): 180
# You have a great figure

# %% [markdown]
# ## Question 21

# %%
velocity = float(input('Please insert velocity(mph): '))
if velocity > 70:
    print('giving traffic ticket')
# Out:
# Please insert velocity(mph): 135
# giving traffic ticket

# %% [markdown]
# ## Question 22

# %%
velocity = float(input('Please insert velocity(mph): '))
if velocity > 85:
    print('fine $70')
elif velocity > 70:
    print('fine $35')
# Out:
# Please insert velocity(mph): 100
# fine $70

# %% [markdown]
# ## Question 23

# %%
listen_time = float(input('Please insert listen_time(hour): '))
if listen_time > 4:
    print('Listening to music for too long may harm your ears')
else:
    print('Have fun listening to music')
# Out:
# Please insert listen_time(hour): 4.1
# Listening to music for too long may harm your ears

# %% [markdown]
# ## Question 24

# %%
traffic_status = input('Please insert traffic_status: ')
distance = float(input('Please insert distance(mile): '))
if traffic_status == 'flow':
    cost = distance*0.05
    print(cost)
elif traffic_status == 'normal':
    cost = distance*0.07
    print(cost)
elif traffic_status == "dense":
    cost = distance*0.1
    print(cost)
# Out:
# Please insert traffic_status: flow
# Please insert distance(mile): 15
# 0.75

# %% [markdown]
# ## Question 25

# %%
score = int(input('Please insert score: '))
if score >= 50:
    print('Pass')
else:
    print('Fail')
# Out:
# Please insert score: 78
# Pass

# %% [markdown]
# ## Question 26

# %%
score = int(input('Please insert score: '))
if score >= 80:
    print('A')
elif score >= 70:
    print('B')
elif score >= 60:
    print('C')
elif score >= 50:
    print('D')
else:
    print('F')
# Out:
# Please insert score: 84
# A

# %% [markdown]
# ## Question 27

# %%
isMember = input('Please insert isMember: ')
bill = float(input('Please insert bill: '))
if isMember == 'yes':
    if bill >= 5000:
        discount = bill*0.15
    elif bill >= 1000:
        discount = bill*0.10
    elif bill >= 500:
        discount = bill*0.05
    else:
        discount = 0
    print(discount)
else:
    discount = 0
    print(discount)
# Out:
# Please insert isMember: no
# Please insert bill: 700
# 0

# %% [markdown]
# ## Question 28

# %%
currency = input('Please insert currency: ')
amount = float(input('Please insert amount: '))
if currency == 'USD':
    THB = amount*0.85
    print(THB)
elif currency == 'JPY':
    THB = amount*0.0077
    print(THB)
# Out:
# Please insert currency: USD
# Please insert amount: 100
# 85.0

# %% [markdown]
# ## Question 29

# %%
order = input('Please order: ')
amount = int(input('Please insert amount: '))
if order == 'scrambled egg':
    cost = amount*7
    print(cost)
elif order == 'omelet':
    cost = amount*10
    print(cost)
elif order == 'egg Benedict':
    cost = amount*5
    print(cost)
else:
    print('Our restaurant has only scrambled eggs, omelettes, and eggs Benedict')
# Out:
# Please order: scrambled egg
# Please insert amount: 2
# 14

# %% [markdown]
# ## Question 30

# %%
order = input('Please order: ')
if order == 'scrambled egg':
    print('recommended to order with toast')
elif order == 'omelet':
    print('recommended to order with hash brown')
elif order == 'egg Benedict':
    print('recommended to order with salad')
else:
    print('Our restaurant has only scrambled eggs, omelettes, and eggs Benedict')
# Out:
# Please order: scrambled egg
# recommended to order with toast
